# %% [markdown]
# <a href="https://colab.research.google.com/github/Pratik-Bhatia/Data-Analysis/blob/main/Movies_Dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

columns_names=['color', 'director_name', 'num_critic_for_reviews', 'duration',
                'gross', 'movie_title', 'num_user_for_reviews', 'country',
                'cotent_rating', 'budget', 'title_year', 'imdb_score', 'genre']
movies=pd.read_csv('/content/movies.csv',
                   sep='|',
                   header=None,
                   names=columns_names,
                   skiprows=3)
movies
# Out:
#     color      director_name num_critic_for_reviews duration        gross  \
# 0   Color  Christopher Nolan                  813.0    164.0  448130642.0
# 1       ?        Doug Walker                      ?        ?            ?
# 2   Color     Andrew Stanton                  462.0    132.0   73058679.0
# 3   Color          Sam Raimi                  392.0    156.0  336530303.0
# 4   Color       Nathan Greno                  324.0    100.0  200807262.0
# ..    ...                ...                    ...      ...          ...
# 92  Color         James Gunn                  653.0    121.0  333130696.0
# 93  Color  Christopher Nolan                  712.0    169.0  187991439.0
# 94  Color  Christopher Nolan                  642.0    148.0  292568851.0
# 95  Color       Hideaki Anno                    1.0    120.0            ?
# 96  Color      Peter Jackson                  645.0    182.0  303001229.0
#
#                                           movie_title num_user_for_reviews  \
# ...

# %%
movies.na_values='?'
movies
# Out:
#     color      director_name num_critic_for_reviews duration        gross  \
# 0   Color  Christopher Nolan                  813.0    164.0  448130642.0
# 1       ?        Doug Walker                      ?        ?            ?
# 2   Color     Andrew Stanton                  462.0    132.0   73058679.0
# 3   Color          Sam Raimi                  392.0    156.0  336530303.0
# 4   Color       Nathan Greno                  324.0    100.0  200807262.0
# ..    ...                ...                    ...      ...          ...
# 92  Color         James Gunn                  653.0    121.0  333130696.0
# 93  Color  Christopher Nolan                  712.0    169.0  187991439.0
# 94  Color  Christopher Nolan                  642.0    148.0  292568851.0
# 95  Color       Hideaki Anno                    1.0    120.0            ?
# 96  Color      Peter Jackson                  645.0    182.0  303001229.0
#
#                                           movie_title num_user_for_reviews  \
# ...

# %%
movies.head()
# Out:
#    color      director_name num_critic_for_reviews duration        gross  \
# 0  Color  Christopher Nolan                  813.0    164.0  448130642.0
# 1      ?        Doug Walker                      ?        ?            ?
# 2  Color     Andrew Stanton                  462.0    132.0   73058679.0
# 3  Color          Sam Raimi                  392.0    156.0  336530303.0
# 4  Color       Nathan Greno                  324.0    100.0  200807262.0
#
#                                          movie_title num_user_for_reviews  \
# 0                             The Dark Knight Rises                2701.0
# 1  Star Wars: Episode VII - The Force Awakens    ...                    ?
# 2                                       John Carter                 738.0
# 3                                      Spider-Man 3                1902.0
# 4                                           Tangled                 387.0
#
#   country cotent_rating         budget title_year  imdb_score        genre
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-4055769e2fc1> in <cell line: 1>()
# ----> 1 plotPerColumnDistribution(movies, 26,26)
#
# NameError: name 'plotPerColumnDistribution' is not defined
