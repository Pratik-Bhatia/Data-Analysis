# %% [markdown]
# <a href="https://colab.research.google.com/github/Pratik-Bhatia/Data-Analysis/blob/main/reading_playstore_excel_sheet.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

data_url='https://github.com/ine-rmotr-projects/project-files/files/4086772/playstore.xlsx'

df=pd.read_excel(data_url,
                 usecols=['App', 'Rating', 'Installs', 'Rating', 'Genres', 'Last_Updated'])
df.head()
# Out:
#                                                  App  Rating     Installs  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook     4.1      10,000+
# 1                                Coloring book moana     3.9     500,000+
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...     4.7   5,000,000+
# 3                              Sketch - Draw & Paint     4.5  50,000,000+
# 4              Pixel Draw - Number Art Coloring Book     4.3     100,000+
#
#                       Genres      Last_Updated
# 0               Art & Design   January 7, 2018
# 1  Art & Design;Pretend Play  January 15, 2018
# 2               Art & Design    August 1, 2018
# 3               Art & Design      June 8, 2018
# 4    Art & Design;Creativity     June 20, 2018

# %%
df['Last_Updated'] = pd.to_datetime(df['Last_Updated'])
df.head()
# Out:
#                                                  App  Rating     Installs  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook     4.1      10,000+
# 1                                Coloring book moana     3.9     500,000+
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...     4.7   5,000,000+
# 3                              Sketch - Draw & Paint     4.5  50,000,000+
# 4              Pixel Draw - Number Art Coloring Book     4.3     100,000+
#
#                       Genres Last_Updated
# 0               Art & Design   2018-01-07
# 1  Art & Design;Pretend Play   2018-01-15
# 2               Art & Design   2018-08-01
# 3               Art & Design   2018-06-08
# 4    Art & Design;Creativity   2018-06-20

# %%
playstore_df=df.sort_values('Rating', ascending=False).head(25)
playstore_df
# Out:
#                                                    App  Rating    Installs  \
# 99                      ipsy: Makeup, Beauty, and Tips     4.9  1,000,000+
# 61                      CDL Practice Test 2018 Edition     4.9    100,000+
# 79                             Tickets + PDA 2018 Exam     4.9  1,000,000+
# 64               DMV Permit Practice Test 2018 Edition     4.9    100,000+
# 177           eBoox new: Reader for fb2 epub zip books     4.9     50,000+
# 55   Tickets SDA 2018 and Exam from the State Traff...     4.9    100,000+
# 74                          Tickets SDA 2019 + Exam RF     4.8    500,000+
# 161                        ReadEra – free ebook reader     4.8  1,000,000+
# 151         Free Books - Spirit Fanfiction and Stories     4.8  1,000,000+
# 196                         Job Search by ZipRecruiter     4.8  1,000,000+
# 70   Fines of the State Traffic Safety Inspectorate...     4.8  5,000,000+
# ...
