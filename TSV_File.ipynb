# %% [markdown]
# <a href="https://colab.research.google.com/github/Pratik-Bhatia/Data-Analysis/blob/main/TSV_File.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# TSV With The Simpsons episodes
# (Tabular Separated Values)

# %%
import pandas as pd
import numpy as np

col_names = ['Title', 'Air date', 'Production code', 'Season', 'Number in season',
             'Number in series', 'US viewers (million)', 'Views', 'IMDB rating']

select_cols=['Title','Air date','Production code','IMDB rating']

df=pd.read_csv('/content/simpsons-episodes.tsv',
               sep='\t',
               names=col_names,
              usecols=select_cols,
               skiprows=4,
               index_col='Production code',
               na_values=['no_val'],
               )
df
# Out:
#                                                              Title  Air date  \
# Production code
# 7F01             Two Cars in Every Garage and Three Eyes on Eve...   1/11/90
# 7F08                                                           NaN  15/11/90
# 7F06                                            Bart the Daredevil   6/12/90
# NaN                                         Bart Gets Hit by a Car   10/1/91
# 7F13                        Homer vs. Lisa and the 8th Commandment    7/2/91
# ...                                                            ...       ...
# PABF07                                          At Long Last Leave   19/2/12
# PABF08                                       How I Wet Your Mother   11/3/12
# PABF18                                  Adventures in Baby-Getting   4/11/12
# SABF08                                                       Diggs    9/3/14
# SABF13                                       Days of Future Future   13/4/14
#
# ...
