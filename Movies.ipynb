# %% [markdown]
# <a href="https://colab.research.google.com/github/Pratik-Bhatia/Data-Analysis/blob/main/Movies.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

column_names=['color', 'director_name', 'num_critic_for_reviews', 'duration',
                'gross', 'movie_title', 'num_user_for_reviews', 'country',
                'cotent_rating', 'budget', 'title_year', 'imdb_score', 'genre']
df=pd.read_csv('/content/Movie.csv',
               sep='|',
               header=None,
              names=column_names,
                na_values= '?',
               thousands=',',
               index_col='movie_title'
               )
df
# Out:
#                                                     color      director_name  \
# movie_title
# Avatar                                              Color      James Cameron
# Pirates of the Caribbean: At World's End            Color     Gore Verbinski
# Spectre                                             Color         Sam Mendes
# The Dark Knight Rises                               Color  Christopher Nolan
# Star Wars: Episode VII - The Force Awakens     ...    NaN        Doug Walker
# ...                                                   ...                ...
# Guardians of the Galaxy                             Color         James Gunn
# Interstellar                                        Color  Christopher Nolan
# Inception                                           Color  Christopher Nolan
# Godzilla Resurgence                                 Color       Hideaki Anno
# The Hobbit: An Unexpected Journey                   Color      Peter Jackson
#
# ...

# %%
def test_budget():
    assert df.loc[:, 'budget'].min() == 105000000.0

# %%
def test_country():
    assert '?' not in df.country.unique()

# %%
def test_shape():
  assert df.shape==(100,12)
